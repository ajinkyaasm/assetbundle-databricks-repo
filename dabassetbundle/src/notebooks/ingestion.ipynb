# %%
dbutils.widgets.text("catalog_name","")

# %%
catalog_name = dbutils.widgets.get("catalog_name")

# %%
# %sql
SELECT * FROM workspace.minifigs.minifigs_table

# %%
df = spark.sql(f"SELECT * FROM {catalog_name}.minifigs.minifigs_table")

# %%
df.display()
